# %% [markdown]
# # CUREYA INTERNSHIP
# # TASK - 6
# # Author : Vidhi Bharadwaj

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df= pd.read_csv(r"C:\Users\bhara\AppData\Local\Programs\Python\Python38\Scripts\water_potability.csv")
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df.shape
# Out:
# (3276, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %% [markdown]
# # Preprocessing the dataset

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# # Filling all the Null values

# %%
df['ph']= df['ph'].fillna(df['ph'].mean())
df['Sulfate']= df['Sulfate'].fillna(df['Sulfate'].mean())
df['Trihalomethanes']= df['Trihalomethanes'].fillna(df['Trihalomethanes'].mean())

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# Now we have no null values in our dataset

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.displot(df['Potability'])

# %% [markdown]
# 0.0 indicates not safe for drinking and 1.0 indicate safe for drinking

# %%
sns.displot(df['ph'])

# %%
sns.displot(df['Hardness'])

# %%
sns.displot(df['Solids'])

# %%
df.hist(figsize=(12, 10))
# Out:
# array([[<AxesSubplot:title={'center':'ph'}>,
#         <AxesSubplot:title={'center':'Hardness'}>,
#         <AxesSubplot:title={'center':'Solids'}>],
#        [<AxesSubplot:title={'center':'Chloramines'}>,
#         <AxesSubplot:title={'center':'Sulfate'}>,
#         <AxesSubplot:title={'center':'Conductivity'}>],
#        [<AxesSubplot:title={'center':'Organic_carbon'}>,
#         <AxesSubplot:title={'center':'Trihalomethanes'}>,
#         <AxesSubplot:title={'center':'Turbidity'}>],
#        [<AxesSubplot:title={'center':'Potability'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.subplots(figsize = (12,9))
#plt.xticks(rotation=30)
sns.barplot(data = df)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,6))
sns.regplot(x='Sulfate',y='Conductivity',data=df)
plt.ylim(0,)
# Out:
# (0.0, 781.9355628369625)

# %% [markdown]
# # Coorelation Matrix

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Train-Test Split

# %%
X=df.drop(['Potability'], axis=1)
y=df['Potability']

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import cross_val_score
def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    print("Accuracy is", model.score(x_test, y_test)*100)
    score = cross_val_score(model, x, y, cv=5)
    print("Cross validation is",np.mean(score)*100)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model, X, y)
# Out:
# Accuracy is 62.27106227106227
# Cross validation is 61.01954943213555

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model, X, y)
# Out:
# Accuracy is 59.584859584859586
# Cross validation is 58.24292496741761

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model = RandomForestClassifier()
classify(model, X, y)
# Out:
# Accuracy is 67.88766788766789
# Cross validation is 64.13396015639546

# %%
model = ExtraTreesClassifier()
classify(model, X, y)
# Out:
# Accuracy is 69.71916971916971
# Cross validation is 63.76740830385403

# %% [markdown]
# # Confusion Matrix

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[455,  55],
#        [202, 107]], dtype=int64)

# %%
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>
